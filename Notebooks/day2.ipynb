# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
import re

# %%
corpus=[]
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review=review.lower()
    corpus.append(review)

# %%
corpus
# Out:
# ['narendra damodardas modi a   born    september       is an indian politician who has served as the prime minister of india since    may      ',
#  'modi was the chief minister of gujarat from      to      and is the member of parliament  mp  for varanasi ',
#  'he is a member of the bharatiya janata party  bjp  and of the rashtriya swayamsevak sangh  rss   a right wing hindutva paramilitary volunteer organisation ',
#  'he is india s third longest serving prime minister  and the longest serving prime minister outside the indian national congress ',
#  ' b   modi was born and raised in vadnagar  where he completed his secondary education ',
#  'he was introduced to the rss at the age of eight  becoming a full time worker for the organisation in gujarat in      ',
#  'the rss assigned him to the bjp in       and he rose through the party hierarchy  becoming general secretary in      ',
#  ' c  in       modi was appointed chief minister of gujarat and elected to the legislative assembly soon after ',
#  'his administration is considered complicit in the      gujarat violence d  in which over       people  mostly muslim  were killed  with many others raped or mutilated ',
#  ' e  an investigation authorised by the supreme court found no evidence to prosecute modi ',
#  ' f  while his policies as chief minister were credited for encouraging economic growth  his administration was criticised for failing to significantly improve health  poverty and education indices in the state ',
#  ' g   in the      indian general election  modi led the bjp to a parliamentary majority  the first for a party since      ',
#  'his administration increased direct foreign investment and reduced spending on healthcare  education  and social welfare ',
#  'modi began a high profile sanitation campaign  introduced the goods and services tax  and weakened or abolished environmental and labour laws ',
#  'his demonetisation of banknotes in      sparked controversy ',
#  'a      airstrike against an alleged terrorist camp in pakistan failed to hit targets of significance       but had nationalist appeal ',
#  '     after winning a second term in       modi s administration revoked the special status of jammu and kashmir ',
#  'the same year it introduced the citizenship amendment act  prompting widespread protests and spurring the      delhi riots in which muslims were targeted by hindu mobs ',
#  '             three controversial farm laws led to widespread protests by farmers  eventually causing their repeal ',
#  'modi oversaw india s response to the covid    pandemic which  according to the who  killed     million indians ',
#  '         in the      general election  the bjp lost its majority in the lower house of parliament and formed a government leading a coalition ',
#  'in modi s third term  a terrorist attack in pahalgam led to the military conflict with pakistan  which resulted in a ceasefire ',
#  'under modi s tenure  india has experienced democratic backsliding  or the weakening of democratic institutions  individual rights  and freedom of expression ',
#  ' h          as prime minister  he has received consistently high approval ratings ',
#  '             modi has been described as engineering a political realignment towards right wing politics ',
#  'he remains a controversial figure domestically and internationally  over his hindu nationalist beliefs and handling of the gujarat violence  which have been cited as evidence of a majoritarian and exclusionary social agenda ']

# %%
nltk.download('stopwords')
nltk.download('wordnet')
corpus = []
for i in range(len(sentences)):
    # Remove special characters using Regex (Keep only a-z and A-Z)
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    
    # Convert to lowercase
    review = review.lower()
    
    # Split into words
    review = review.split()
    
    # Remove stopwords and apply Lemmatization
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    
    # Rejoin the words back into a sentence
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nishc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nishc\AppData\Roaming\nltk_data...

# %%
corpus
# Out:
# ['narendra damodardas modi born september indian politician served prime minister india since may',
#  'modi chief minister gujarat member parliament mp varanasi',
#  'member bharatiya janata party bjp rashtriya swayamsevak sangh rss right wing hindutva paramilitary volunteer organisation',
#  'india third longest serving prime minister longest serving prime minister outside indian national congress',
#  'b modi born raised vadnagar completed secondary education',
#  'introduced rss age eight becoming full time worker organisation gujarat',
#  'rss assigned bjp rose party hierarchy becoming general secretary',
#  'c modi appointed chief minister gujarat elected legislative assembly soon',
#  'administration considered complicit gujarat violence people mostly muslim killed many others raped mutilated',
#  'e investigation authorised supreme court found evidence prosecute modi',
#  'f policy chief minister credited encouraging economic growth administration criticised failing significantly improve health poverty education index state',
#  'g indian general election modi led bjp parliamentary majority first party since',
#  'administration increased direct foreign investment reduced spending healthcare education social welfare',
#  'modi began high profile sanitation campaign introduced good service tax weakened abolished environmental labour law',
#  'demonetisation banknote sparked controversy',
#  'airstrike alleged terrorist camp pakistan failed hit target significance nationalist appeal',
#  'winning second term modi administration revoked special status jammu kashmir',
#  'year introduced citizenship amendment act prompting widespread protest spurring delhi riot muslim targeted hindu mob',
#  'three controversial farm law led widespread protest farmer eventually causing repeal',
#  'modi oversaw india response covid pandemic according killed million indian',
#  'general election bjp lost majority lower house parliament formed government leading coalition',
#  'modi third term terrorist attack pahalgam led military conflict pakistan resulted ceasefire',
#  'modi tenure india experienced democratic backsliding weakening democratic institution individual right freedom expression',
#  'h prime minister received consistently high approval rating',
#  'modi described engineering political realignment towards right wing politics',
#  'remains controversial figure domestically internationally hindu nationalist belief handling gujarat violence cited evidence majoritarian exclusionary social agenda']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
x=cv.fit_transform(corpus)

# %%
cv.vocabulary_
# Out:
# {'narendra': 126,
#  'damodardas': 44,
#  'modi': 121,
#  'born': 23,
#  'september': 172,
#  'indian': 93,
#  'politician': 143,
#  'served': 173,
#  'prime': 146,
#  'minister': 119,
#  'india': 92,
#  'since': 178,
#  'may': 115,
#  'chief': 28,
#  'gujarat': 79,
#  'member': 116,
#  'parliament': 137,
#  'mp': 123,
#  'varanasi': 200,
#  'bharatiya': 21,
#  'janata': 101,
#  'party': 139,
#  'bjp': 22,
#  'rashtriya': 153,
#  'swayamsevak': 188,
#  'sangh': 167,
#  'rss': 166,
#  'right': 163,
#  'wing': 207,
#  'hindutva': 86,
#  'paramilitary': 136,
#  'volunteer': 202,
#  'organisation': 129,
#  'third': 195,
#  'longest': 109,
#  'serving': 175,
#  'outside': 131,
#  'national': 127,
#  'congress': 35,
#  'raised': 151,
#  'vadnagar': 199,
#  'completed': 32,
#  'secondary': 170,
#  'education': 52,
#  'introduced': 97,
#  'age': 4,
#  'eight': 53,
#  'becoming': 18,
#  'full': 74,
#  'time': 197,
#  'worker': 209,
#  'assigned': 13,
#  'rose': 165,
#  'hierarchy': 83,
#  'general': 75,
#  'secretary': 171,
#  'appointed': 10,
#  'elected': 54,
#  'legislative': 108,
#  'assembly': 12,
#  'soon': 180,
#  'administration': 3,
#  'considered': 36,
#  'complicit': 33,
#  'violence': 201,
#  'people': 140,
#  'mostly': 122,
#  'muslim': 124,
#  'killed': 103,
#  'many': 114,
#  'others': 130,
#  'raped': 152,
#  'mutilated': 125,
#  'investigation': 98,
#  'authorised': 15,
#  'supreme': 187,
#  'court': 40,
#  'found': 72,
#  'evidence': 60,
#  'prosecute': 149,
#  'policy': 141,
#  'credited': 42,
#  'encouraging': 56,
#  'economic': 51,
#  'growth': 78,
#  'criticised': 43,
#  'failing': 65,
#  'significantly': 177,
#  'improve': 89,
#  'health': 81,
#  'poverty': 145,
#  'index': 91,
#  'state': 185,
#  'election': 55,
#  'led': 107,
#  'parliamentary': 138,
#  'majority': 113,
#  'first': 69,
#  'increased': 90,
#  'direct': 49,
#  'foreign': 70,
#  'investment': 99,
#  'reduced': 157,
#  'spending': 183,
#  'healthcare': 82,
#  'social': 179,
#  'welfare': 205,
#  'began': 19,
#  'high': 84,
#  'profile': 147,
#  'sanitation': 168,
#  'campaign': 25,
#  'good': 76,
#  'service': 174,
#  'tax': 191,
#  'weakened': 203,
#  'abolished': 0,
#  'environmental': 58,
#  'labour': 104,
#  'law': 105,
#  'demonetisation': 47,
#  'banknote': 17,
#  'sparked': 181,
#  'controversy': 39,
#  'airstrike': 6,
#  'alleged': 7,
#  'terrorist': 194,
#  'camp': 24,
#  'pakistan': 134,
#  'failed': 64,
#  'hit': 87,
#  'target': 189,
#  'significance': 176,
#  'nationalist': 128,
#  'appeal': 9,
#  'winning': 208,
#  'second': 169,
#  'term': 193,
#  'revoked': 162,
#  'special': 182,
#  'status': 186,
#  'jammu': 100,
#  'kashmir': 102,
#  'year': 210,
#  'citizenship': 30,
#  'amendment': 8,
#  'act': 2,
#  'prompting': 148,
#  'widespread': 206,
#  'protest': 150,
#  'spurring': 184,
#  'delhi': 45,
#  'riot': 164,
#  'targeted': 190,
#  'hindu': 85,
#  'mob': 120,
#  'three': 196,
#  'controversial': 38,
#  'farm': 66,
#  'farmer': 67,
#  'eventually': 59,
#  'causing': 26,
#  'repeal': 159,
#  'oversaw': 132,
#  'response': 160,
#  'covid': 41,
#  'pandemic': 135,
#  'according': 1,
#  'million': 118,
#  'lost': 110,
#  'lower': 111,
#  'house': 88,
#  'formed': 71,
#  'government': 77,
#  'leading': 106,
#  'coalition': 31,
#  'attack': 14,
#  'pahalgam': 133,
#  'military': 117,
#  'conflict': 34,
#  'resulted': 161,
#  'ceasefire': 27,
#  'tenure': 192,
#  'experienced': 62,
#  'democratic': 46,
#  'backsliding': 16,
#  'weakening': 204,
#  'institution': 95,
#  'individual': 94,
#  'freedom': 73,
#  'expression': 63,
#  'received': 156,
#  'consistently': 37,
#  'approval': 11,
#  'rating': 154,
#  'described': 48,
#  'engineering': 57,
#  'political': 142,
#  'realignment': 155,
#  'towards': 198,
#  'politics': 144,
#  'remains': 158,
#  'figure': 68,
#  'domestically': 50,
#  'internationally': 96,
#  'belief': 20,
#  'handling': 80,
#  'cited': 29,
#  'majoritarian': 112,
#  'exclusionary': 61,
#  'agenda': 5}
